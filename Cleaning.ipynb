# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_columns = None

# %%
df = pd.read_csv('data/kc_house_data.csv')
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0          5650     1.0         NaN   0.0          3      7        1180
# 1          7242     2.0         0.0   0.0          3      7        2170
# 2         10000     1.0         0.0   0.0          3      6         770
# 3          5000     1.0         0.0   0.0          5      7        1050
# 4          8080     1.0         0.0   0.0          3      8        1680
# ...         ...     ...         ...   ...        ...    ...         ...
# 21592      1131     3.0         0.0   0.0          3      8        1530
# 21593      5813     2.0         0.0   0.0          3      8        2310
# 21594      1350     2.0         0.0   0.0          3      7        1020
# 21595      2388     2.0         NaN   0.0          3      8        1600
# 21596      1076     2.0         0.0   0.0          3      7        1020
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0               0.0      1955           0.0    98178  47.5112 -122.257
# 1             400.0      1951        1991.0    98125  47.7210 -122.319
# 2               0.0      1933           NaN    98028  47.7379 -122.233
# 3             910.0      1965           0.0    98136  47.5208 -122.393
# 4               0.0      1987           0.0    98074  47.6168 -122.045
# ...             ...       ...           ...      ...      ...      ...
# 21592           0.0      2009           0.0    98103  47.6993 -122.346
# 21593           0.0      2014           0.0    98146  47.5107 -122.362
# 21594           0.0      2009           0.0    98144  47.5944 -122.299
# 21595           0.0      2004           0.0    98027  47.5345 -122.069
# 21596           0.0      2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# **There are missing values in waterfront, view, yr_renovated.**

# %%
#convert date
df['date'] = pd.to_datetime(df['date'])
df['date'].max(), df['date'].min()
# Out:
# (Timestamp('2015-05-27 00:00:00'), Timestamp('2014-05-02 00:00:00'))

# %% [markdown]
# Assumption: since the data is one year old, we ignore house appreciation in price.

# %%
#create year column
df['year_sold'] = pd.DatetimeIndex(df['date']).year

# %%
df.drop('date', axis=1, inplace=True)

# %% [markdown]
# # Deal with missing data

# %% [markdown]
# Assumption: we assume that missing data in renovated year means the house has been renovated. we also assume that missing data in waterfront means that the house doesn't have  waterfront view

# %%
df['yr_renovated'].fillna(value=0.0, inplace=True)
df['waterfront'].fillna(value=0.0, inplace=True)

# %% [markdown]
# There are 63 houses missing 'view' values.

# %% [markdown]
# One of them has a waterfront. So, we replace NaN of this one with 4.0 which is

# %%
view_missing = df[df['view'].isna()].sort_values('price', ascending=False)

# %%
view_missing[view_missing['waterfront'] ==1]
# Out:
#               id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 1313  7558700030  5300000.0         6        6.0         7390     24829
#
#       floors  waterfront  view  condition  grade  sqft_above sqft_basement  \
# 1313     2.0         1.0   NaN          4     12        5000        2390.0
#
#       yr_built  yr_renovated  zipcode      lat    long  sqft_living15  \
# 1313      1991           0.0    98040  47.5631 -122.21           4320
#
#       sqft_lot15  year_sold
# 1313       24619       2015

# %%
df.loc[df['id'] == 7558700030, 'view'] = 4.0

# %%
round(df[df['waterfront']==1]['view'].mean())
# Out:
# 4.0

# %%
round(df[df['waterfront']==0]['view'].mean())
# Out:
# 0.0

# %%
df['view'].fillna(value=0.0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   price          21597 non-null  float64
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  float64
#  8   view           21597 non-null  float64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  object
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  float64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  year_sold      21597 non-null  int64
# dtypes: float64(8), int64(12), object(1)
# memory usage: 3.5+ MB

# %%
df['house_age'] = df['year_sold'] - df['yr_built']

# %%
df['reno_age'] = np.where(df['yr_renovated'] != 0, df['year_sold']-df['yr_renovated'], df['house_age'] )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   price          21597 non-null  float64
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  float64
#  8   view           21597 non-null  float64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  object
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  float64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
#  17  long           21597 non-null  float64
#  18  sqft_living15  21597 non-null  int64
#  19  sqft_lot15     21597 non-null  int64
#  20  year_sold      21597 non-null  int64
#  21  house_age      21597 non-null  int64
#  22  reno_age       21597 non-null  float64
# dtypes: float64(9), int64(13), object(1)
# memory usage: 3.8+ MB

# %% [markdown]
# # Potential Outliers

# %%
cleaning_df = df.drop(['yr_built', 'yr_renovated'], axis=1)

# %%
cleaning_df.hist(figsize=(20,20), bins='auto');

# %% [markdown]
# # Duplicate Data

# %%
cleaning_df[cleaning_df.duplicated(subset=['lat','long'], keep=False)].sort_values('lat')
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20909  8141310040  246950.0         3       3.00         1670      4440
# 20670  8141310030  256703.0         3       2.00         1670      4441
# 16521  5595900345  460000.0         4       2.75         3460     13168
# 5142   5595900280  235000.0         3       1.00         1050      7670
# 8422   9432900180  307999.0         4       2.75         2420      8438
# ...           ...       ...       ...        ...          ...       ...
# 19286  7418700040  234000.0         3       1.00          960      9624
# 10526   253600160  384950.0         3       2.50         1860      3690
# 7525    253600150  380000.0         2       2.50         1860      3504
# 8522    293720180  415000.0         3       2.50         1980      4274
# 747     293720140  449950.0         3       2.50         2170      4912
#
#        floors  waterfront  view  condition  grade  sqft_above sqft_basement  \
# 20909     1.0         0.0   0.0          3      7        1670           0.0
# 20670     1.0         0.0   0.0          3      7        1670           0.0
# 16521     2.0         0.0   0.0          4      8        3460           0.0
# 5142      1.5         0.0   0.0          5      7        1050           0.0
# 8422      2.0         0.0   0.0          3      8        2420           0.0
# ...       ...         ...   ...        ...    ...         ...           ...
# 19286     1.0         0.0   0.0          3      7         960           0.0
# 10526     2.0         0.0   0.0          3      7        1860           0.0
# 7525      2.0         0.0   0.0          3      7        1860           0.0
# 8522      2.0         0.0   0.0          3      7        1980           0.0
# 747       2.0         0.0   0.0          3      7        2170           0.0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  year_sold  \
# 20909    98022  47.1948 -121.975           1670        4622       2014
# 20670    98022  47.1948 -121.975           1670        4622       2014
# 16521    98022  47.2046 -121.996           1500        7670       2015
# 5142     98022  47.2046 -121.996           1220        7670       2015
# 8422     98022  47.2091 -122.009           2420        8580       2014
# ...        ...      ...      ...            ...         ...        ...
# 19286    98155  47.7758 -122.301           1540        9624       2015
# 10526    98028  47.7760 -122.239           1870        4394       2014
# 7525     98028  47.7760 -122.239           1860        4246       2014
# 8522     98028  47.7767 -122.239           2000        4394       2014
# 747      98028  47.7767 -122.239           2010        4395       2014
#
#        house_age  reno_age
# 20909          0       0.0
# 20670          0       0.0
# 16521         83      29.0
# 5142          60      60.0
# 8422          18      18.0
# ...          ...       ...
# 19286         62      62.0
# 10526         14      14.0
# 7525          14      14.0
# 8522          11      11.0
# 747           11      11.0
#
# [1505 rows x 21 columns]

# %%
cleaning_df[cleaning_df.duplicated() == True]
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 3947   1825069031  550000.0         4       1.75         2410      8447
# 20038  8648900110  555000.0         3       2.50         1940      3211
#
#        floors  waterfront  view  condition  grade  sqft_above sqft_basement  \
# 3947      2.0         0.0   3.0          4      8        2060         350.0
# 20038     2.0         0.0   0.0          3      8        1940           0.0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  year_sold  \
# 3947     98074  47.6499 -122.088           2520       14789       2014
# 20038    98027  47.5644 -122.093           1880        3078       2014
#
#        house_age  reno_age
# 3947          78      34.0
# 20038          5       5.0

# %% [markdown]
# After check out these rows, I don't feel that they are identical.

# %%
zipoutliers = cleaning_df.groupby('zipcode')['price'].describe()
zipoutliers
# Out:
#          count          mean            std       min       25%        50%  \
# zipcode
# 98001    361.0  2.811949e+05   98837.430520  100000.0  215000.0   260000.0
# 98002    199.0  2.342840e+05   52041.448659   95000.0  199975.0   235000.0
# 98003    280.0  2.941113e+05  107597.662236  128000.0  229000.0   267475.0
# 98004    317.0  1.356524e+06  746094.067159  425000.0  845000.0  1150000.0
# 98005    168.0  8.102897e+05  268979.168276  400000.0  637775.0   765475.0
# ...        ...           ...            ...       ...       ...        ...
# 98177    255.0  6.764194e+05  436379.739508  245560.0  428500.0   554000.0
# 98178    262.0  3.106128e+05  161044.746227   90000.0  223250.0   278277.0
# 98188    136.0  2.890783e+05  103106.579944  110000.0  228750.0   264000.0
# 98198    280.0  3.028967e+05  154906.277482   95000.0  216375.0   265000.0
# 98199    317.0  7.921879e+05  398428.721573  323000.0  535000.0   689800.0
#
#                75%        max
# zipcode
# 98001     320000.0   850000.0
# 98002     268500.0   389000.0
# 98003     330000.0   950000.0
# 98004    1690000.0  7060000.0
# 98005     911250.0  1960000.0
# ...            ...        ...
# 98177     739475.0  3800000.0
# 98178     349792.5  1700000.0
# 98188     335000.0   707000.0
# 98198     340000.0  1350000.0
# 98199     950000.0  3200000.0
#
# [70 rows x 8 columns]

# %%
cleaning_df['sqft_basement'].value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
#           ...
# 1990.0        1
# 3500.0        1
# 2500.0        1
# 3000.0        1
# 516.0         1
# Name: sqft_basement, Length: 304, dtype: int64

# %%
cleaning_df['sqft_basement'].replace('?', 0.0,inplace=True)

# %%
cleaning_df['sqft_basement'].value_counts()
# Out:
# 0.0       13280
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
#           ...
# 1284.0        1
# 3500.0        1
# 2500.0        1
# 3000.0        1
# 143.0         1
# Name: sqft_basement, Length: 303, dtype: int64

# %%
cleaning_df['sqft_basement'] = cleaning_df['sqft_basement'].apply(lambda x: int(x[:-2]))

# %%
cleaning_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   price          21597 non-null  float64
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  float64
#  8   view           21597 non-null  float64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  zipcode        21597 non-null  int64
#  14  lat            21597 non-null  float64
#  15  long           21597 non-null  float64
#  16  sqft_living15  21597 non-null  int64
#  17  sqft_lot15     21597 non-null  int64
#  18  year_sold      21597 non-null  int64
#  19  house_age      21597 non-null  int64
#  20  reno_age       21597 non-null  float64
# dtypes: float64(8), int64(13)
# memory usage: 3.5 MB
